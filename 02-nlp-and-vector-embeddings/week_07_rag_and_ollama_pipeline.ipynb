# %%
# Student asks
question = "What is scarcity?"

# Find best analogy (manual for demo)
if "scarcity" in question or "not enough" in question:
    analogy = "1 chocolate and 14 students, not enough chocolate for everyone."
elif "condition of seed germination" in question:
    analogy = "Seed needs water, warmth and air like a baby needs milk."
else:
    analogy = "No match found"

# Print
print(f"Question: {question}")
print(f"Analogy: {analogy}")

# Ollama explanation (concept only, no real connection)
print("\nOllama would explain this simply and warmly.")
print("Example: 'Imagine you have 1 chocolate but 14 friends...'")
# Out:
# Question: What is scarcity?
# Analogy: 1 chocolate and 14 students, not enough chocolate for everyone.
#
# Ollama would explain this simply and warmly.
# Example: 'Imagine you have 1 chocolate but 14 friends...'
