# %%
# Import Libraries
from kivy.app import App
from kivy.uix.button import Button

# Class is Company (App)
class Kognit(App):

# Function is StoreFront (What user sees)
    def build(self):
        return Button(text = "Kognit Worksss!")

Kognit().run()
